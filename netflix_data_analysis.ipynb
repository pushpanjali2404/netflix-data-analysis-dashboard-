# %% [markdown]
# # 🎬 Netflix Data Analysis
# This notebook performs basic exploratory data analysis on the Netflix dataset.

# %%
import pandas as pd

file_path = "netflix1 (1).csv"

# Load CSV file
df = pd.read_csv(file_path)
df.head()

# %%
# Dataset shape
df.shape

# %%
# Column information
df.info()

# %%
# Missing values
df.isna().sum()

# %%
# Descriptive statistics
df.describe(include='all')

# %%
# Movies vs TV Shows count
df['type'].value_counts()

# %%
# Content added per year
df['release_year'].value_counts().sort_index().tail(10)

# %% [markdown]
# ## ✅ Conclusion
# This notebook gives an overview of Netflix content trends and dataset structure.
